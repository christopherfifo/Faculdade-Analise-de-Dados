# %%
import pandas as pd

# Passo 1: Ler o arquivo pulando as primeiras 4 linhas e definindo a linha 5 como cabeçalho
dados = pd.read_excel(
    "PLANILHA DE TERCERIZADOS - FEVEREIRO 2024.xlsx",
    sheet_name="COLABORADORES",
    skiprows=4,
    header=0
)

dados = dados.dropna(how="all", axis=1)

dados = dados.dropna(how="all")

display(dados)
# Out:
#     Nº CONTRATO          PROCESSO SEI               NOME DO COLABORADOR  \
# 0       02/2023  23477.011356/2022-91             AIRLENE GOMES FREITAS
# 1       02/2023  23477.011356/2022-91       ANA EDUARDA SEABRA DA COSTA
# 2       02/2023  23477.011356/2022-91     BRYAN RAFAEL OLIVEIRA MARQUES
# 3       02/2023  23477.011356/2022-91       CLÁUDIA REGINA MACIEL NUNES
# 4       02/2023  23477.011356/2022-91             CLOTILDE DIAS CARDOSO
# ..          ...                   ...                               ...
# 155     18/2023  23872.003407/2023-20            JOSIANE RAMOS DA SILVA
# 156     25/2023  23872.005321/2023-31           ANTONIO AUGUSTO ANDRADE
# 157     25/2023  23872.005321/2023-31  PAULO ROGERIO ADONIS DE OLIVEIRA
# 158     25/2023  23872.005321/2023-31           JARDSON DE SOUZA BRASIL
# 159     32/2023  23872.007602/2023-29         WELLINGTON DA SILVA MATOS
#
#                 CPF                      CARGO           ÁREA DE ATUAÇÃO  \
# 0    ***.403.852-**         RECEPCIONISTA 30 H                    UMULTI
# 1    ***.824.192-**         RECEPCIONISTA 30 H      RECEPÇÃO AMBULATÓRIO
# 2    ***.193.892-**         RECEPCIONISTA 30 H  LOBBY (RECEPÇÃO CENTRAL)
# 3    ***.465.212-**         RECEPCIONISTA 30 H        RECEPÇÃO PRINCIPAL
# 4    ***.452.192-**         RECEPCIONISTA 30 H               AMBULATÓRIO
# ..              ...                        ...                       ...
# 155  ***.257.382-**                  CAMAREIRA    HOSPITAL UNIVERSITÁRIO
# 156  ***.960.968-**              Eletrotécnico    HOSPITAL UNIVERSITÁRIO
# 157  ***.396.732-**      Técnico em eletrônica    HOSPITAL UNIVERSITÁRIO
# 158  ***.581.002-**      Técnico em eletrônica    HOSPITAL UNIVERSITÁRIO
# 159  ***.033.782-**  TECNICO EM ELETROMECANICA    HOSPITAL UNIVERSITÁRIO
#
#         LOTAÇÃO    HUAP-UFF
# 0    HU-HUNIFAP     HU-FURG
# 1    HU-HUNIFAP  HUPAA-UFAL
# 2    HU-HUNIFAP      HU-UFS
# 3    HU-HUNIFAP      HC-UFG
# 4    HU-HUNIFAP     HUL-UFS
# ..          ...         ...
# 155  HU-HUNIFAP         NaN
# 156  HU-HUNIFAP         NaN
# 157  HU-HUNIFAP         NaN
# 158  HU-HUNIFAP         NaN
# 159  HU-HUNIFAP         NaN
#
# [160 rows x 8 columns]

# %%
dados.to_csv("tercerizados_limpos.csv", index=False, encoding="utf-8-sig")

dados = pd.read_csv("tercerizados_limpos.csv")
dados.head(10)
# Out:
#   Nº CONTRATO          PROCESSO SEI            NOME DO COLABORADOR  \
# 0     02/2023  23477.011356/2022-91          AIRLENE GOMES FREITAS
# 1     02/2023  23477.011356/2022-91    ANA EDUARDA SEABRA DA COSTA
# 2     02/2023  23477.011356/2022-91  BRYAN RAFAEL OLIVEIRA MARQUES
# 3     02/2023  23477.011356/2022-91    CLÁUDIA REGINA MACIEL NUNES
# 4     02/2023  23477.011356/2022-91          CLOTILDE DIAS CARDOSO
# 5     02/2023  23477.011356/2022-91      DAIANE DE ALMEIDA CARDOSO
# 6     02/2023  23477.011356/2022-91      DULCINEIA LOBATO MONTEIRO
# 7     02/2023  23477.011356/2022-91        EVELYNE CHAGAS DA ROCHA
# 8     02/2023  23477.011356/2022-91     GIOVANA NASCIMENTO BARBOSA
# 9     02/2023  23477.011356/2022-91   HELEN MARA DE ARAUJO MOREIRA
#
#               CPF               CARGO  \
# 0  ***.403.852-**  RECEPCIONISTA 30 H
# 1  ***.824.192-**  RECEPCIONISTA 30 H
# 2  ***.193.892-**  RECEPCIONISTA 30 H
# 3  ***.465.212-**  RECEPCIONISTA 30 H
# 4  ***.452.192-**  RECEPCIONISTA 30 H
# 5  ***.555.102-**  RECEPCIONISTA 30 H
# 6  ***.281.602-**  RECEPCIONISTA 30 H
# 7  ***.149.132-**  RECEPCIONISTA 30 H
# 8  ***.444.442-**  RECEPCIONISTA 30 H
# 9  ***.568.512-**  RECEPCIONISTA 30 H
#
#                                      ÁREA DE ATUAÇÃO     LOTAÇÃO    HUAP-UFF
# 0                                             UMULTI  HU-HUNIFAP     HU-FURG
# 1                               RECEPÇÃO AMBULATÓRIO  HU-HUNIFAP  HUPAA-UFAL
# 2                           LOBBY (RECEPÇÃO CENTRAL)  HU-HUNIFAP      HU-UFS
# 3                                 RECEPÇÃO PRINCIPAL  HU-HUNIFAP      HC-UFG
# 4                                        AMBULATÓRIO  HU-HUNIFAP     HUL-UFS
# 5                           LOBBY (RECEPÇÃO CENTRAL)  HU-HUNIFAP    MCO-UFBA
# 6                               RECEPÇÃO AMBULATÓRIO  HU-HUNIFAP     HU-UFSC
# 7                                             UMULTI  HU-HUNIFAP  HUMAP-UFMS
# 8                                        AMBULATÓRIO  HU-HUNIFAP     HDT-UFT
# 9  UNIDADE DE DIAGNOSTICO POR IMAGEM E DIAGNÓSTIC...  HU-HUNIFAP   HUJB-UFCG
